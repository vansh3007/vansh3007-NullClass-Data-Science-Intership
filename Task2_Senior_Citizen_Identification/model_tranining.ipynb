# %%
import os
import gc
import numpy as np
import pandas as pd
from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.optimizers import Adam


IMAGE_DIR = "../data/UTKFace"
image_paths = []
age_labels = []
gender_labels = []

for filename in tqdm(os.listdir(IMAGE_DIR)):
    try:
        age, gender = filename.split("_")[0:2]
        age = int(age)
        gender = int(gender)
        path = os.path.join(IMAGE_DIR, filename)

        image_paths.append(path)
        age_labels.append(age)
        gender_labels.append(gender)
    except:
        continue


def extract_features(image_paths, size=(96, 96)): 
    features = []
    for img_path in tqdm(image_paths):
        img = Image.open(img_path).convert("L")
        img = img.resize(size)
        features.append(np.array(img))
    features = np.array(features, dtype=np.float32).reshape(-1, size[0], size[1], 1)
    return features / 255.0

X = extract_features(image_paths)
y_age = np.array(age_labels)
y_gender = np.array(gender_labels)

y_combined = np.column_stack((y_gender, y_age))
X_train, X_temp, y_train_combined, y_temp_combined = train_test_split(X, y_combined, test_size=0.2, random_state=42)


gc.collect()

X_val, X_test, y_val_combined, y_test_combined = train_test_split(X_temp, y_temp_combined, test_size=0.5, random_state=42)

y_train_gender, y_train_age = y_train_combined[:, 0], y_train_combined[:, 1]
y_val_gender, y_val_age = y_val_combined[:, 0], y_val_combined[:, 1]
y_test_gender, y_test_age = y_test_combined[:, 0], y_test_combined[:, 1]


input_shape = (96, 96, 1)  
inputs = Input(shape=input_shape)

x = Conv2D(32, (3, 3), activation='relu')(inputs)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(128, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(256, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
x = Flatten()(x)

dense_gender = Dense(256, activation='relu')(x)
dropout_gender = Dropout(0.3)(dense_gender)
output_gender = Dense(1, activation='sigmoid', name='gender_out')(dropout_gender)

dense_age = Dense(256, activation='relu')(x)
dropout_age = Dropout(0.3)(dense_age)
output_age = Dense(1, activation='relu', name='age_out')(dropout_age)

model = Model(inputs=inputs, outputs=[output_gender, output_age])
model.compile(optimizer=Adam(1e-3),
              loss=['binary_crossentropy', 'mae'],
              metrics=['accuracy', 'mae'])

model.summary()


model_path = "best_model.keras"
checkpoint = ModelCheckpoint(model_path, monitor='val_gender_out_accuracy', save_best_only=True, verbose=1, mode='max')
annealer = LearningRateScheduler(lambda epoch: 1e-3 * (0.9 ** epoch))

history = model.fit(
    X_train, [y_train_gender, y_train_age],
    validation_data=(X_val, [y_val_gender, y_val_age]),
    epochs=20,
    batch_size=128,
    callbacks=[checkpoint, annealer]
)


plt.plot(history.history['gender_out_accuracy'], label='Gender Accuracy (Train)')
plt.plot(history.history['val_gender_out_accuracy'], label='Gender Accuracy (Val)')
plt.legend()
plt.title("Gender Accuracy")
plt.show()

plt.plot(history.history['age_out_mae'], label='Age MAE (Train)')
plt.plot(history.history['val_age_out_mae'], label='Age MAE (Val)')
plt.legend()
plt.title("Age MAE")
plt.show()


model.save("age_gender_model.h5")
# Out:
# 100%|██████████| 23708/23708 [00:00<00:00, 198762.63it/s]
# 100%|██████████| 23708/23708 [10:11<00:00, 38.76it/s]
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 96, 96, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 94, 94,    │        320 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 47, 47,    │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 45, 45,    │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 22, 22,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 20, 20,    │     73,856 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 10, 10,    │          0 │ conv2d_2[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 8, 8, 256) │    295,168 │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 4, 4, 256) │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 4096)      │          0 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │  1,048,832 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │  1,048,832 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gender_out (Dense)  │ (None, 1)         │        257 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ age_out (Dense)     │ (None, 1)         │        257 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,486,018 (9.48 MB)
#  Trainable params: 2,486,018 (9.48 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 977ms/step - age_out_loss: 18.9504 - age_out_mae: 18.9505 - gender_out_accuracy: 0.5191 - gender_out_loss: 0.7599 - loss: 19.7104
# Epoch 1: val_gender_out_accuracy improved from -inf to 0.52931, saving model to best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 171s 1s/step - age_out_loss: 18.9327 - age_out_mae: 18.9328 - gender_out_accuracy: 0.5191 - gender_out_loss: 0.7596 - loss: 19.6924 - val_age_out_loss: 14.1372 - val_age_out_mae: 14.1291 - val_gender_out_accuracy: 0.5293 - val_gender_out_loss: 0.6853 - val_loss: 14.8144 - learning_rate: 0.0010
# Epoch 2/20
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - age_out_loss: 14.3511 - age_out_mae: 14.3512 - gender_out_accuracy: 0.5801 - gender_out_loss: 0.6691 - loss: 15.0203
# Epoch 2: val_gender_out_accuracy improved from 0.52931 to 0.70097, saving model to best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - age_out_loss: 14.3493 - age_out_mae: 14.3495 - gender_out_accuracy: 0.5805 - gender_out_loss: 0.6689 - loss: 15.0184 - val_age_out_loss: 12.8076 - val_age_out_mae: 12.7764 - val_gender_out_accuracy: 0.7010 - val_gender_out_loss: 0.5761 - val_loss: 13.3522 - learning_rate: 9.0000e-04
# Epoch 3/20
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 976ms/step - age_out_loss: 12.6739 - age_out_mae: 12.6740 - gender_out_accuracy: 0.7243 - gender_out_loss: 0.5431 - loss: 13.2170
# Epoch 3: val_gender_out_accuracy improved from 0.70097 to 0.74146, saving model to best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - age_out_loss: 12.6706 - age_out_mae: 12.6708 - gender_out_accuracy: 0.7243 - gender_out_loss: 0.5430 - loss: 13.2138 - val_age_out_loss: 12.0121 - val_age_out_mae: 11.9654 - val_gender_out_accuracy: 0.7415 - val_gender_out_loss: 0.5256 - val_loss: 12.4903 - learning_rate: 8.1000e-04
# Epoch 4/20
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - age_out_loss: 10.8617 - age_out_mae: 10.8616 - gender_out_accuracy: 0.7581 - gender_out_loss: 0.5058 - loss: 11.3674
# Epoch 4: val_gender_out_accuracy improved from 0.74146 to 0.76339, saving model to best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 166s 1s/step - age_out_loss: 10.8614 - age_out_mae: 10.8611 - gender_out_accuracy: 0.7581 - gender_out_loss: 0.5058 - loss: 11.3669 - val_age_out_loss: 11.9811 - val_age_out_mae: 11.9572 - val_gender_out_accuracy: 0.7634 - val_gender_out_loss: 0.4805 - val_loss: 12.4367 - learning_rate: 7.2900e-04
# Epoch 5/20
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - age_out_loss: 10.5196 - age_out_mae: 10.5197 - gender_out_accuracy: 0.7786 - gender_out_loss: 0.4651 - loss: 10.9848
# Epoch 5: val_gender_out_accuracy improved from 0.76339 to 0.78870, saving model to best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - age_out_loss: 10.5172 - age_out_mae: 10.5172 - gender_out_accuracy: 0.7786 - gender_out_loss: 0.4651 - loss: 10.9823 - val_age_out_loss: 9.8559 - val_age_out_mae: 9.8340 - val_gender_out_accuracy: 0.7887 - val_gender_out_loss: 0.4539 - val_loss: 10.2866 - learning_rate: 6.5610e-04
# Epoch 6/20
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - age_out_loss: 9.6480 - age_out_mae: 9.6481 - gender_out_accuracy: 0.7898 - gender_out_loss: 0.4421 - loss: 10.0903
# Epoch 6: val_gender_out_accuracy improved from 0.78870 to 0.79502, saving model to best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - age_out_loss: 9.6484 - age_out_mae: 9.6485 - gender_out_accuracy: 0.7898 - gender_out_loss: 0.4421 - loss: 10.0907 - val_age_out_loss: 9.4820 - val_age_out_mae: 9.4645 - val_gender_out_accuracy: 0.7950 - val_gender_out_loss: 0.4287 - val_loss: 9.8919 - learning_rate: 5.9049e-04
# Epoch 7/20
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 863ms/step - age_out_loss: 9.5144 - age_out_mae: 9.5145 - gender_out_accuracy: 0.8021 - gender_out_loss: 0.4260 - loss: 9.9405
# Epoch 7: val_gender_out_accuracy improved from 0.79502 to 0.79882, saving model to best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 134s 896ms/step - age_out_loss: 9.5136 - age_out_mae: 9.5137 - gender_out_accuracy: 0.8021 - gender_out_loss: 0.4259 - loss: 9.9397 - val_age_out_loss: 9.1898 - val_age_out_mae: 9.1735 - val_gender_out_accuracy: 0.7988 - val_gender_out_loss: 0.4155 - val_loss: 9.5881 - learning_rate: 5.3144e-04
# Epoch 8/20
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 868ms/step - age_out_loss: 8.8705 - age_out_mae: 8.8703 - gender_out_accuracy: 0.8137 - gender_out_loss: 0.4061 - loss: 9.2764
# Epoch 8: val_gender_out_accuracy did not improve from 0.79882
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 142s 898ms/step - age_out_loss: 8.8707 - age_out_mae: 8.8704 - gender_out_accuracy: 0.8137 - gender_out_loss: 0.4061 - loss: 9.2765 - val_age_out_loss: 9.6553 - val_age_out_mae: 9.6432 - val_gender_out_accuracy: 0.7832 - val_gender_out_loss: 0.4505 - val_loss: 10.0923 - learning_rate: 4.7830e-04
# Epoch 9/20
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 868ms/step - age_out_loss: 8.8225 - age_out_mae: 8.8225 - gender_out_accuracy: 0.8181 - gender_out_loss: 0.3920 - loss: 9.2145
# Epoch 9: val_gender_out_accuracy improved from 0.79882 to 0.80641, saving model to best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 134s 901ms/step - age_out_loss: 8.8212 - age_out_mae: 8.8212 - gender_out_accuracy: 0.8181 - gender_out_loss: 0.3919 - loss: 9.2131 - val_age_out_loss: 9.1452 - val_age_out_mae: 9.1298 - val_gender_out_accuracy: 0.8064 - val_gender_out_loss: 0.4010 - val_loss: 9.5301 - learning_rate: 4.3047e-04
# Epoch 10/20
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 890ms/step - age_out_loss: 8.3222 - age_out_mae: 8.3222 - gender_out_accuracy: 0.8223 - gender_out_loss: 0.3849 - loss: 8.7070
# Epoch 10: val_gender_out_accuracy improved from 0.80641 to 0.80936, saving model to best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 138s 924ms/step - age_out_loss: 8.3227 - age_out_mae: 8.3227 - gender_out_accuracy: 0.8223 - gender_out_loss: 0.3848 - loss: 8.7075 - val_age_out_loss: 8.3468 - val_age_out_mae: 8.3278 - val_gender_out_accuracy: 0.8094 - val_gender_out_loss: 0.3839 - val_loss: 8.7111 - learning_rate: 3.8742e-04
# Epoch 11/20
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 883ms/step - age_out_loss: 8.2387 - age_out_mae: 8.2386 - gender_out_accuracy: 0.8271 - gender_out_loss: 0.3731 - loss: 8.6117
# Epoch 11: val_gender_out_accuracy improved from 0.80936 to 0.81611, saving model to best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 136s 916ms/step - age_out_loss: 8.2386 - age_out_mae: 8.2385 - gender_out_accuracy: 0.8271 - gender_out_loss: 0.3730 - loss: 8.6115 - val_age_out_loss: 8.1868 - val_age_out_mae: 8.1748 - val_gender_out_accuracy: 0.8161 - val_gender_out_loss: 0.3750 - val_loss: 8.5493 - learning_rate: 3.4868e-04
# Epoch 12/20
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 881ms/step - age_out_loss: 7.9048 - age_out_mae: 7.9048 - gender_out_accuracy: 0.8369 - gender_out_loss: 0.3619 - loss: 8.2667
# Epoch 12: val_gender_out_accuracy improved from 0.81611 to 0.82075, saving model to best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 137s 917ms/step - age_out_loss: 7.9050 - age_out_mae: 7.9050 - gender_out_accuracy: 0.8370 - gender_out_loss: 0.3619 - loss: 8.2669 - val_age_out_loss: 8.0239 - val_age_out_mae: 8.0163 - val_gender_out_accuracy: 0.8208 - val_gender_out_loss: 0.3705 - val_loss: 8.3864 - learning_rate: 3.1381e-04
# Epoch 13/20
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 882ms/step - age_out_loss: 7.9734 - age_out_mae: 7.9734 - gender_out_accuracy: 0.8417 - gender_out_loss: 0.3520 - loss: 8.3253
# Epoch 13: val_gender_out_accuracy improved from 0.82075 to 0.82328, saving model to best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 137s 919ms/step - age_out_loss: 7.9728 - age_out_mae: 7.9728 - gender_out_accuracy: 0.8417 - gender_out_loss: 0.3520 - loss: 8.3247 - val_age_out_loss: 7.8151 - val_age_out_mae: 7.8065 - val_gender_out_accuracy: 0.8233 - val_gender_out_loss: 0.3603 - val_loss: 8.1665 - learning_rate: 2.8243e-04
# Epoch 14/20
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 886ms/step - age_out_loss: 7.7311 - age_out_mae: 7.7311 - gender_out_accuracy: 0.8444 - gender_out_loss: 0.3447 - loss: 8.0758
# Epoch 14: val_gender_out_accuracy improved from 0.82328 to 0.82497, saving model to best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 138s 924ms/step - age_out_loss: 7.7311 - age_out_mae: 7.7312 - gender_out_accuracy: 0.8444 - gender_out_loss: 0.3447 - loss: 8.0759 - val_age_out_loss: 7.7311 - val_age_out_mae: 7.7280 - val_gender_out_accuracy: 0.8250 - val_gender_out_loss: 0.3558 - val_loss: 8.0833 - learning_rate: 2.5419e-04
# Epoch 15/20
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 901ms/step - age_out_loss: 7.6114 - age_out_mae: 7.6114 - gender_out_accuracy: 0.8484 - gender_out_loss: 0.3441 - loss: 7.9555
# Epoch 15: val_gender_out_accuracy improved from 0.82497 to 0.82834, saving model to best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 140s 937ms/step - age_out_loss: 7.6120 - age_out_mae: 7.6119 - gender_out_accuracy: 0.8484 - gender_out_loss: 0.3441 - loss: 7.9560 - val_age_out_loss: 7.9072 - val_age_out_mae: 7.9051 - val_gender_out_accuracy: 0.8283 - val_gender_out_loss: 0.3583 - val_loss: 8.2630 - learning_rate: 2.2877e-04
# Epoch 16/20
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 904ms/step - age_out_loss: 7.5020 - age_out_mae: 7.5020 - gender_out_accuracy: 0.8478 - gender_out_loss: 0.3412 - loss: 7.8433
# Epoch 16: val_gender_out_accuracy improved from 0.82834 to 0.83467, saving model to best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 140s 942ms/step - age_out_loss: 7.5019 - age_out_mae: 7.5019 - gender_out_accuracy: 0.8478 - gender_out_loss: 0.3412 - loss: 7.8431 - val_age_out_loss: 7.6034 - val_age_out_mae: 7.6040 - val_gender_out_accuracy: 0.8347 - val_gender_out_loss: 0.3480 - val_loss: 7.9517 - learning_rate: 2.0589e-04
# Epoch 17/20
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 892ms/step - age_out_loss: 7.4486 - age_out_mae: 7.4486 - gender_out_accuracy: 0.8470 - gender_out_loss: 0.3412 - loss: 7.7898
# Epoch 17: val_gender_out_accuracy did not improve from 0.83467
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 138s 924ms/step - age_out_loss: 7.4482 - age_out_mae: 7.4481 - gender_out_accuracy: 0.8470 - gender_out_loss: 0.3411 - loss: 7.7892 - val_age_out_loss: 7.5716 - val_age_out_mae: 7.5730 - val_gender_out_accuracy: 0.8250 - val_gender_out_loss: 0.3588 - val_loss: 7.9316 - learning_rate: 1.8530e-04
# Epoch 18/20
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 906ms/step - age_out_loss: 7.3786 - age_out_mae: 7.3786 - gender_out_accuracy: 0.8591 - gender_out_loss: 0.3212 - loss: 7.6998
# Epoch 18: val_gender_out_accuracy improved from 0.83467 to 0.83551, saving model to best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 140s 941ms/step - age_out_loss: 7.3784 - age_out_mae: 7.3783 - gender_out_accuracy: 0.8590 - gender_out_loss: 0.3212 - loss: 7.6996 - val_age_out_loss: 7.4990 - val_age_out_mae: 7.4982 - val_gender_out_accuracy: 0.8355 - val_gender_out_loss: 0.3401 - val_loss: 7.8380 - learning_rate: 1.6677e-04
# Epoch 19/20
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 909ms/step - age_out_loss: 7.2716 - age_out_mae: 7.2715 - gender_out_accuracy: 0.8566 - gender_out_loss: 0.3207 - loss: 7.5922
# Epoch 19: val_gender_out_accuracy improved from 0.83551 to 0.84057, saving model to best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 141s 944ms/step - age_out_loss: 7.2714 - age_out_mae: 7.2712 - gender_out_accuracy: 0.8566 - gender_out_loss: 0.3207 - loss: 7.5919 - val_age_out_loss: 7.4511 - val_age_out_mae: 7.4544 - val_gender_out_accuracy: 0.8406 - val_gender_out_loss: 0.3349 - val_loss: 7.7891 - learning_rate: 1.5009e-04
# Epoch 20/20
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 908ms/step - age_out_loss: 7.0951 - age_out_mae: 7.0952 - gender_out_accuracy: 0.8618 - gender_out_loss: 0.3148 - loss: 7.4100
# Epoch 20: val_gender_out_accuracy did not improve from 0.84057
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 140s 939ms/step - age_out_loss: 7.0953 - age_out_mae: 7.0954 - gender_out_accuracy: 0.8617 - gender_out_loss: 0.3149 - loss: 7.4103 - val_age_out_loss: 7.5267 - val_age_out_mae: 7.5304 - val_gender_out_accuracy: 0.8326 - val_gender_out_loss: 0.3372 - val_loss: 7.8677 - learning_rate: 1.3509e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
